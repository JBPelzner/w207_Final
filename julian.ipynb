# %%
import pandas as pd

# %%
gdpr = pd.read_csv("GDPRDataAge5.csv")
gdpr
# Out:
#                                           package_name        country  \
# 0                               bluphant.games.gravity  United States
# 1                 air.com.pepiplay.pepibathliteandroid  United States
# 2                       com.intellijoy.sightwords.lite  United States
# 3            com.kevinbradford.games.barnyardgamesfree  United States
# 4                   com.kevinbradford.games.firstgrade  United States
# 5               com.kevinbradford.games.preschoolgames  United States
# 6                                  com.lego.bricksmore  United States
# 7                                com.lego.duplo.trains  United States
# 8                   com.Mykaelos.FrankiesBabyFireworks  United States
# 9                             com.pdemp.myreadingwords  United States
# 10                                    dk.spatifo.dublo  United States
# 11                                 zok.android.numbers  United States
# ...

# %%
gdpr['pregdpr.permissions'].nunique()
# Out:
# 451

# %%
max
